# %%
import os
from shoe_detection import detect_shoe

# %%
images = ['side.jpg', 'side2.jpg', 'boots.jpg', 'behind.jpg', 'top.jpg', 'holding.jpg', 'onfeet.jpg', 'human.jpg','sole.jpg']

for image in images:
    image_path = os.path.join('images', image)
    detect_shoe(image_path, 10,30,)
